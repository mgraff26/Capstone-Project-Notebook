# %% [markdown]
# # Best Neighborhood in Philladelphia to open a Resturant #

# %% [markdown]
# ## Neighborhood Postal Code Data

# %% [markdown]
# https://opendata.arcgis.com/datasets/ad233733f89242af9a1f9e52d60d1e4e_0.geojson

# %% [markdown]
# ## Neighborhood Average Income

# %% [markdown]
# http://zipatlas.com/us/pa/philadelphia/zip-code-comparison/median-household-income.htm

# %% [markdown]
# ## Number of Resturants Per a Capita in Each Neighborhood

# %% [markdown]
# https://api.foursquare.com
# http://zipatlas.com/us/pa/philadelphia/zip-code-comparison/median-age.htm

# %% [markdown]
# ## Crime Per a Capita in Each Neighborhood

# %% [markdown]
# https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&skipfields=cartodb_id,the_geom,the_geom_webmercator&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%272020-01-01%27%20AND%20dispatch_date_time%20%3C%20%272021-01-01%27

# %% [markdown]
# ## Conclusion ##
# - Which neighboorhood is most profitable to open a high end resturant?
# - Which neighboorhood is most profitabl to open a cheap resturant?
# - Is the neigboorhood that would be most profitable safe?
